# %%
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# C:\Users\peter\AppData\Local\Temp\ipykernel_20908\1305367288.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:85% !important; }</style>

# %%
book_df = pd.read_excel('PENbooklist.xlsx', "Sorted by Author & Title")
book_df
# Out:
#                       Author  \
# 0     Àbíké-Íyímídé, Faridah
# 1         Acevedo, Elizabeth
# 2         Acevedo, Elizabeth
# 3         Acevedo, Elizabeth
# 4         Acevedo, Elizabeth
# ...                      ...
# 2527            Zia, Farhana
# 2528         Ziemke, Kristin
# 2529              Zoboi, Ibi
# 2530              Zoboi, Ibi
# 2531        Zunon, Elizabeth
#
#                                                   Title  \
# 0                                         Ace of Spades
# 1                                    Clap When You Land
# 2                                            The Poet X
# 3                                            The Poet X
# 4                                            The Poet X
# ...                                                 ...
# 2527                             The Garden of My Imaan
# 2528  Read the World: Rethinking Literacy for Empath...
# 2529                                    American Street
# ...

# %%
book_df.fillna("", inplace = True)
book_df
# Out:
#                       Author  \
# 0     Àbíké-Íyímídé, Faridah
# 1         Acevedo, Elizabeth
# 2         Acevedo, Elizabeth
# 3         Acevedo, Elizabeth
# 4         Acevedo, Elizabeth
# ...                      ...
# 2527            Zia, Farhana
# 2528         Ziemke, Kristin
# 2529              Zoboi, Ibi
# 2530              Zoboi, Ibi
# 2531        Zunon, Elizabeth
#
#                                                   Title  \
# 0                                         Ace of Spades
# 1                                    Clap When You Land
# 2                                            The Poet X
# 3                                            The Poet X
# 4                                            The Poet X
# ...                                                 ...
# 2527                             The Garden of My Imaan
# 2528  Read the World: Rethinking Literacy for Empath...
# 2529                                    American Street
# ...

# %%
# book_df.rename(columns={'Unnamed: 8': 'Blank'}, inplace= True)
# book_df.drop(columns=['Blank'], inplace= True)
book_df.rename(columns = {'Type_of_Ban': 'Ban'}, inplace = True)
book_df.rename(columns = {'Second Author': 'Second_Author'}, inplace = True)
book_df.rename(columns = {'Removal Date': 'Removal_Date'}, inplace = True)
book_df.rename(columns = {'Origin of Challenge': 'Origin_of_Challenge'}, inplace = True)

book_df
# Out:
#                       Author  \
# 0     Àbíké-Íyímídé, Faridah
# 1         Acevedo, Elizabeth
# 2         Acevedo, Elizabeth
# 3         Acevedo, Elizabeth
# 4         Acevedo, Elizabeth
# ...                      ...
# 2527            Zia, Farhana
# 2528         Ziemke, Kristin
# 2529              Zoboi, Ibi
# 2530              Zoboi, Ibi
# 2531        Zunon, Elizabeth
#
#                                                   Title  \
# 0                                         Ace of Spades
# 1                                    Clap When You Land
# 2                                            The Poet X
# 3                                            The Poet X
# 4                                            The Poet X
# ...                                                 ...
# 2527                             The Garden of My Imaan
# 2528  Read the World: Rethinking Literacy for Empath...
# 2529                                    American Street
# ...

# %%
book_df.to_csv('cleansed_ban_data.csv', index = False)

# %%
book_df.dtypes
# Out:
# Author                               object
# Title                                object
# Type of Ban                          object
# Secondary Author(s)                  object
# State                                object
# District                             object
# Date of Challenge/Removal    datetime64[ns]
# Origin of Challenge                  object
# Latitude                            float64
# Longitude                           float64
# dtype: object

# %%
state_district_df = pd.read_excel('PENbooklist.xlsx', "Sorted by State & District")
state_district_df = state_district_df.fillna('')
state_district_df.drop(columns=['Illustrator(s)', 'Translator(s)'], inplace= True)
state_district_df.head()
# Out:
#       State                        District Origin of Challenge  \
# 0    Alaska       Anchorage School District       Administrator
# 1  Arkansas  Siloam Springs School District    Formal Challenge
# 2   Florida          Brevard Public Schools       Administrator
# 3   Florida          Brevard Public Schools       Administrator
# 4   Florida          Brevard Public Schools       Administrator
#
#   Date of Challenge/Removal                         Type of Ban  \
# 0                2021-10-01  Banned in Libraries and Classrooms
# 1                2022-01-01  Banned in Libraries and Classrooms
# 2                2022-05-01        Banned Pending Investigation
# 3                2022-03-01        Banned Pending Investigation
# 4                2022-05-01        Banned Pending Investigation
#
#            Author                                              Title  \
# 0    Kobabe, Maia                             Gender Queer: A Memoir
# ...

# %%
state_district_df.to_csv('state_data_cleansed.csv', index = False)
